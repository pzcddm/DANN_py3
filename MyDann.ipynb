# %% [markdown]
# # ATMSPY_DANN
# 套用github上的模板，然后用在自己采集的数据使用DANN

# %%
import random
import os
import sys
import torch.backends.cudnn as cudnn
import torch.optim as optim
import torch.utils.data
import numpy as np
from data_loader import GetLoader
from torchvision import datasets
from torchvision import transforms
from torch.utils.data import TensorDataset
from mymodel import MyCNNModel
from mytest import mytest
#from test import test

# %%
source_x=np.loadtxt('collect_data/pzc/05_25_21_16/freqDomain/freqSignal.csv',delimiter=',',dtype=np.float32)
source_y=np.loadtxt('collect_data/pzc/05_25_21_16/label.csv',delimiter=',',dtype=np.int64)
target_x=np.loadtxt('collect_data/qjw/05_25_21_30/freqDomain/freqSignal.csv',delimiter=',',dtype=np.float32)
target_y=np.loadtxt('collect_data/qjw/05_25_21_30/label.csv',delimiter=',',dtype=np.int64)

# %%
cuda = True
cudnn.benchmark = True
lr = 1e-3
batch_size = 128
image_size = 28
n_epoch = 100
source_dataset_name='source'
target_dataset_name='target'
model_root='models'
manual_seed = random.randint(1, 10000)
random.seed(manual_seed)
torch.manual_seed(manual_seed)

# %%
source_x=torch.from_numpy(source_x)
source_y=torch.from_numpy(source_y)
target_x=torch.from_numpy(target_x)
target_y=torch.from_numpy(target_y)
dataset_source=TensorDataset(source_x,source_y)
dataset_target=TensorDataset(target_x,target_y)

# %%
dataloader_source = torch.utils.data.DataLoader(
    dataset=dataset_source,
    batch_size=batch_size,
    shuffle=True,
    num_workers=8)

dataloader_target = torch.utils.data.DataLoader(
    dataset=dataset_target,
    batch_size=batch_size,
    shuffle=True,
    num_workers=8)

# %%
# load model

my_net = MyCNNModel()

# setup optimizer

optimizer = optim.Adam(my_net.parameters(), lr=lr)

loss_class = torch.nn.NLLLoss()
loss_domain = torch.nn.NLLLoss()

if cuda:
    my_net = my_net.cuda()
    loss_class = loss_class.cuda()
    loss_domain = loss_domain.cuda()

for p in my_net.parameters():
    p.requires_grad = True

# %%
# training
best_accu_t = 0.0
for epoch in range(n_epoch):

    len_dataloader = min(len(dataloader_source), len(dataloader_target))
    data_source_iter = iter(dataloader_source)
    data_target_iter = iter(dataloader_target)

    for i in range(len_dataloader):

        p = float(i + epoch * len_dataloader) / n_epoch / len_dataloader
        alpha = 2. / (1. + np.exp(-10 * p)) - 1

        # training model using source data
        data_source = data_source_iter.next()
        s_img, s_label = data_source

        my_net.zero_grad()
        batch_size = len(s_label)

        domain_label = torch.zeros(batch_size).long()

        if cuda:
            s_img = s_img.cuda()
            s_label = s_label.cuda()
            domain_label = domain_label.cuda()


        class_output, domain_output = my_net(input_data=s_img, alpha=alpha)
        err_s_label = loss_class(class_output, s_label)
        err_s_domain = loss_domain(domain_output, domain_label)

        # training model using target data
        data_target = data_target_iter.next()
        t_img, _ = data_target

        batch_size = len(t_img)

        domain_label = torch.ones(batch_size).long()

        if cuda:
            t_img = t_img.cuda()
            domain_label = domain_label.cuda()

        _, domain_output = my_net(input_data=t_img, alpha=alpha)
        err_t_domain = loss_domain(domain_output, domain_label)
        err = err_t_domain + err_s_domain + err_s_label
        err.backward()
        optimizer.step()

        sys.stdout.write('\r epoch: %d, [iter: %d / all %d], err_s_label: %f, err_s_domain: %f, err_t_domain: %f' \
              % (epoch, i + 1, len_dataloader, err_s_label.data.cpu().numpy(),
                 err_s_domain.data.cpu().numpy(), err_t_domain.data.cpu().item()))
        sys.stdout.flush()
        torch.save(my_net, '{0}/mnist_mnistm_model_epoch_current.pth'.format(model_root))

    print('\n')
    accu_s = mytest(source_dataset_name)
    print('Accuracy of the %s dataset: %f' % ('source: ', accu_s))
    accu_t = mytest(target_dataset_name)
    print('Accuracy of the %s dataset: %f\n' % ('target: ', accu_t))
    if accu_t > best_accu_t:
        best_accu_s = accu_s
        best_accu_t = accu_t
        torch.save(my_net, '{0}/mnist_mnistm_model_epoch_best.pth'.format(model_root))
# Out:
#  epoch: 0, [iter: 3 / all 3], err_s_label: 2.063153, err_s_domain: 0.708486, err_t_domain: 1.177854
#
# Accuracy of the source:  dataset: 0.233333
# Accuracy of the target:  dataset: 0.226667
#
#  epoch: 1, [iter: 3 / all 3], err_s_label: 1.921163, err_s_domain: 0.600157, err_t_domain: 0.912000
#
# Accuracy of the source:  dataset: 0.153333
# Accuracy of the target:  dataset: 0.216667
#
#  epoch: 2, [iter: 3 / all 3], err_s_label: 1.897044, err_s_domain: 0.619466, err_t_domain: 0.821900
#
# Accuracy of the source:  dataset: 0.146667
# Accuracy of the target:  dataset: 0.213333
#
#  epoch: 3, [iter: 3 / all 3], err_s_label: 1.705546, err_s_domain: 0.626782, err_t_domain: 0.765227
#
# Accuracy of the source:  dataset: 0.160000
# Accuracy of the target:  dataset: 0.236667
#
#  epoch: 4, [iter: 3 / all 3], err_s_label: 1.564777, err_s_domain: 0.688987, err_t_domain: 0.724135
#
# Accuracy of the source:  dataset: 0.213333
# Accuracy of the target:  dataset: 0.313333
#
#  epoch: 5, [iter: 3 / all 3], err_s_label: 1.512378, err_s_domain: 0.717745, err_t_domain: 0.672247
#
# Accuracy of the source:  dataset: 0.270000
# Accuracy of the target:  dataset: 0.393333
#
#  epoch: 6, [iter: 3 / all 3], err_s_label: 1.499362, err_s_domain: 0.742617, err_t_domain: 0.657875
#
# Accuracy of the source:  dataset: 0.360000
# Accuracy of the target:  dataset: 0.476667
#
#  epoch: 7, [iter: 3 / all 3], err_s_label: 1.294950, err_s_domain: 0.734224, err_t_domain: 0.630322
#
# Accuracy of the source:  dataset: 0.490000
# Accuracy of the target:  dataset: 0.533333
#
#  epoch: 8, [iter: 3 / all 3], err_s_label: 1.182803, err_s_domain: 0.726650, err_t_domain: 0.663283
#
# Accuracy of the source:  dataset: 0.596667
# Accuracy of the target:  dataset: 0.576667
#
#  epoch: 9, [iter: 3 / all 3], err_s_label: 1.098338, err_s_domain: 0.692532, err_t_domain: 0.671232
#
# Accuracy of the source:  dataset: 0.680000
# Accuracy of the target:  dataset: 0.586667
#
#  epoch: 10, [iter: 3 / all 3], err_s_label: 1.033378, err_s_domain: 0.675389, err_t_domain: 0.697589
#
# Accuracy of the source:  dataset: 0.736667
# Accuracy of the target:  dataset: 0.603333
#
#  epoch: 11, [iter: 3 / all 3], err_s_label: 1.061193, err_s_domain: 0.666327, err_t_domain: 0.702406
#
# Accuracy of the source:  dataset: 0.780000
# Accuracy of the target:  dataset: 0.613333
#
#  epoch: 12, [iter: 3 / all 3], err_s_label: 0.920710, err_s_domain: 0.652969, err_t_domain: 0.730423
#
# Accuracy of the source:  dataset: 0.826667
# Accuracy of the target:  dataset: 0.626667
#
#  epoch: 13, [iter: 3 / all 3], err_s_label: 0.779828, err_s_domain: 0.643927, err_t_domain: 0.712479
#
# Accuracy of the source:  dataset: 0.836667
# Accuracy of the target:  dataset: 0.626667
#
#  epoch: 14, [iter: 3 / all 3], err_s_label: 0.723223, err_s_domain: 0.637738, err_t_domain: 0.722920
#
# Accuracy of the source:  dataset: 0.870000
# Accuracy of the target:  dataset: 0.626667
#
#  epoch: 15, [iter: 3 / all 3], err_s_label: 0.725663, err_s_domain: 0.646743, err_t_domain: 0.697860
#
# Accuracy of the source:  dataset: 0.916667
# Accuracy of the target:  dataset: 0.633333
#
#  epoch: 16, [iter: 3 / all 3], err_s_label: 0.594675, err_s_domain: 0.673927, err_t_domain: 0.712377
#
# Accuracy of the source:  dataset: 0.953333
# Accuracy of the target:  dataset: 0.633333
#
#  epoch: 17, [iter: 3 / all 3], err_s_label: 0.525799, err_s_domain: 0.685100, err_t_domain: 0.696999
#
# Accuracy of the source:  dataset: 0.970000
# Accuracy of the target:  dataset: 0.646667
#
#  epoch: 18, [iter: 3 / all 3], err_s_label: 0.477297, err_s_domain: 0.667094, err_t_domain: 0.691760
#
# Accuracy of the source:  dataset: 0.980000
# Accuracy of the target:  dataset: 0.640000
#
#  epoch: 19, [iter: 3 / all 3], err_s_label: 0.453995, err_s_domain: 0.650644, err_t_domain: 0.694000
#
# Accuracy of the source:  dataset: 0.993333
# Accuracy of the target:  dataset: 0.666667
#
#  epoch: 20, [iter: 3 / all 3], err_s_label: 0.466748, err_s_domain: 0.658343, err_t_domain: 0.667082
#
# Accuracy of the source:  dataset: 0.996667
# Accuracy of the target:  dataset: 0.680000
#
#  epoch: 21, [iter: 3 / all 3], err_s_label: 0.455291, err_s_domain: 0.675259, err_t_domain: 0.692850
#
# Accuracy of the source:  dataset: 1.000000
# Accuracy of the target:  dataset: 0.700000
#
#  epoch: 22, [iter: 3 / all 3], err_s_label: 0.308120, err_s_domain: 0.649754, err_t_domain: 0.704754
#
# Accuracy of the source:  dataset: 1.000000
# Accuracy of the target:  dataset: 0.700000
#
#  epoch: 23, [iter: 3 / all 3], err_s_label: 0.354315, err_s_domain: 0.661037, err_t_domain: 0.675568
#
# Accuracy of the source:  dataset: 1.000000
# Accuracy of the target:  dataset: 0.696667
#
#  epoch: 24, [iter: 3 / all 3], err_s_label: 0.281250, err_s_domain: 0.663003, err_t_domain: 0.668289
#
# Accuracy of the source:  dataset: 1.000000
# Accuracy of the target:  dataset: 0.670000
#
#  epoch: 25, [iter: 3 / all 3], err_s_label: 0.218979, err_s_domain: 0.665972, err_t_domain: 0.686719
#
# Accuracy of the source:  dataset: 1.000000
# Accuracy of the target:  dataset: 0.676667
#
#  epoch: 26, [iter: 3 / all 3], err_s_label: 0.206526, err_s_domain: 0.632400, err_t_domain: 0.686232
#
# Accuracy of the source:  dataset: 1.000000
# Accuracy of the target:  dataset: 0.686667
#
#  epoch: 27, [iter: 3 / all 3], err_s_label: 0.207836, err_s_domain: 0.642084, err_t_domain: 0.657404
#
# Accuracy of the source:  dataset: 1.000000
# Accuracy of the target:  dataset: 0.703333
#
#  epoch: 28, [iter: 3 / all 3], err_s_label: 0.167848, err_s_domain: 0.654380, err_t_domain: 0.664528
#
# Accuracy of the source:  dataset: 1.000000
# Accuracy of the target:  dataset: 0.716667
#
#  epoch: 29, [iter: 3 / all 3], err_s_label: 0.189139, err_s_domain: 0.659971, err_t_domain: 0.673554
#
# Accuracy of the source:  dataset: 1.000000
# Accuracy of the target:  dataset: 0.713333
#
#  epoch: 30, [iter: 3 / all 3], err_s_label: 0.158449, err_s_domain: 0.650526, err_t_domain: 0.663178
#
# Accuracy of the source:  dataset: 1.000000
# Accuracy of the target:  dataset: 0.726667
#
#  epoch: 31, [iter: 3 / all 3], err_s_label: 0.252089, err_s_domain: 0.656801, err_t_domain: 0.683053
#
# Accuracy of the source:  dataset: 1.000000
# Accuracy of the target:  dataset: 0.723333
#
#  epoch: 32, [iter: 3 / all 3], err_s_label: 0.175649, err_s_domain: 0.652186, err_t_domain: 0.665479
#
# Accuracy of the source:  dataset: 1.000000
# Accuracy of the target:  dataset: 0.706667
#
#  epoch: 33, [iter: 3 / all 3], err_s_label: 0.180662, err_s_domain: 0.619832, err_t_domain: 0.692336
#
# Accuracy of the source:  dataset: 1.000000
# Accuracy of the target:  dataset: 0.706667
#
#  epoch: 34, [iter: 3 / all 3], err_s_label: 0.155011, err_s_domain: 0.657676, err_t_domain: 0.662908
#
# Accuracy of the source:  dataset: 1.000000
# Accuracy of the target:  dataset: 0.723333
#
#  epoch: 35, [iter: 3 / all 3], err_s_label: 0.171800, err_s_domain: 0.652033, err_t_domain: 0.682555
#
# Accuracy of the source:  dataset: 1.000000
# Accuracy of the target:  dataset: 0.716667
#
#  epoch: 36, [iter: 3 / all 3], err_s_label: 0.147475, err_s_domain: 0.604028, err_t_domain: 0.622676
#
# Accuracy of the source:  dataset: 1.000000
# Accuracy of the target:  dataset: 0.730000
#
#  epoch: 37, [iter: 3 / all 3], err_s_label: 0.100333, err_s_domain: 0.671792, err_t_domain: 0.604670
#
# Accuracy of the source:  dataset: 1.000000
# Accuracy of the target:  dataset: 0.736667
#
#  epoch: 38, [iter: 3 / all 3], err_s_label: 0.194381, err_s_domain: 0.661047, err_t_domain: 0.641891
#
# Accuracy of the source:  dataset: 1.000000
# Accuracy of the target:  dataset: 0.746667
#
#  epoch: 39, [iter: 3 / all 3], err_s_label: 0.118044, err_s_domain: 0.639207, err_t_domain: 0.662577
#
# Accuracy of the source:  dataset: 1.000000
# Accuracy of the target:  dataset: 0.743333
#
#  epoch: 40, [iter: 3 / all 3], err_s_label: 0.185207, err_s_domain: 0.611782, err_t_domain: 0.658283
#
# Accuracy of the source:  dataset: 1.000000
# Accuracy of the target:  dataset: 0.746667
#
#  epoch: 41, [iter: 3 / all 3], err_s_label: 0.134700, err_s_domain: 0.627146, err_t_domain: 0.608315
#
# Accuracy of the source:  dataset: 1.000000
# Accuracy of the target:  dataset: 0.753333
#
#  epoch: 42, [iter: 3 / all 3], err_s_label: 0.102689, err_s_domain: 0.645573, err_t_domain: 0.636320
#
# Accuracy of the source:  dataset: 1.000000
# Accuracy of the target:  dataset: 0.760000
#
#  epoch: 43, [iter: 3 / all 3], err_s_label: 0.156717, err_s_domain: 0.627483, err_t_domain: 0.625802
#
# Accuracy of the source:  dataset: 1.000000
# Accuracy of the target:  dataset: 0.763333
#
#  epoch: 44, [iter: 3 / all 3], err_s_label: 0.135362, err_s_domain: 0.538878, err_t_domain: 0.600985
#
# Accuracy of the source:  dataset: 1.000000
# Accuracy of the target:  dataset: 0.763333
#
#  epoch: 45, [iter: 3 / all 3], err_s_label: 0.135073, err_s_domain: 0.602036, err_t_domain: 0.575885
#
# Accuracy of the source:  dataset: 1.000000
# Accuracy of the target:  dataset: 0.750000
#
#  epoch: 46, [iter: 3 / all 3], err_s_label: 0.164678, err_s_domain: 0.582963, err_t_domain: 0.706415
#
# Accuracy of the source:  dataset: 1.000000
# Accuracy of the target:  dataset: 0.740000
#
#  epoch: 47, [iter: 3 / all 3], err_s_label: 0.184244, err_s_domain: 0.628955, err_t_domain: 0.565762
#
# Accuracy of the source:  dataset: 1.000000
# Accuracy of the target:  dataset: 0.733333
#
#  epoch: 48, [iter: 3 / all 3], err_s_label: 0.127327, err_s_domain: 0.630437, err_t_domain: 0.546131
#
# Accuracy of the source:  dataset: 1.000000
# Accuracy of the target:  dataset: 0.753333
#
#  epoch: 49, [iter: 3 / all 3], err_s_label: 0.168704, err_s_domain: 0.571342, err_t_domain: 0.567144
#
# Accuracy of the source:  dataset: 1.000000
# Accuracy of the target:  dataset: 0.763333
#
#  epoch: 50, [iter: 3 / all 3], err_s_label: 0.083976, err_s_domain: 0.599184, err_t_domain: 0.614291
#
# Accuracy of the source:  dataset: 1.000000
# Accuracy of the target:  dataset: 0.756667
#
#  epoch: 51, [iter: 3 / all 3], err_s_label: 0.136230, err_s_domain: 0.607835, err_t_domain: 0.573833
#
# Accuracy of the source:  dataset: 1.000000
# Accuracy of the target:  dataset: 0.763333
#
#  epoch: 52, [iter: 3 / all 3], err_s_label: 0.080654, err_s_domain: 0.600261, err_t_domain: 0.658229
#
# Accuracy of the source:  dataset: 1.000000
# Accuracy of the target:  dataset: 0.756667
#
#  epoch: 53, [iter: 3 / all 3], err_s_label: 0.137398, err_s_domain: 0.585415, err_t_domain: 0.630415
#
# Accuracy of the source:  dataset: 1.000000
# Accuracy of the target:  dataset: 0.763333
#
#  epoch: 54, [iter: 3 / all 3], err_s_label: 0.120637, err_s_domain: 0.562496, err_t_domain: 0.560568
#
# Accuracy of the source:  dataset: 1.000000
# Accuracy of the target:  dataset: 0.763333
#
#  epoch: 55, [iter: 3 / all 3], err_s_label: 0.093927, err_s_domain: 0.528226, err_t_domain: 0.601881
#
# Accuracy of the source:  dataset: 1.000000
# Accuracy of the target:  dataset: 0.763333
#
#  epoch: 56, [iter: 3 / all 3], err_s_label: 0.123177, err_s_domain: 0.573020, err_t_domain: 0.701142
#
# Accuracy of the source:  dataset: 1.000000
# Accuracy of the target:  dataset: 0.753333
#
#  epoch: 57, [iter: 3 / all 3], err_s_label: 0.135295, err_s_domain: 0.580351, err_t_domain: 0.627957
#
# Accuracy of the source:  dataset: 1.000000
# Accuracy of the target:  dataset: 0.740000
#
#  epoch: 58, [iter: 3 / all 3], err_s_label: 0.226115, err_s_domain: 0.589472, err_t_domain: 0.581072
#
# Accuracy of the source:  dataset: 1.000000
# Accuracy of the target:  dataset: 0.773333
#
#  epoch: 59, [iter: 3 / all 3], err_s_label: 0.176711, err_s_domain: 0.627566, err_t_domain: 0.657179
#
# Accuracy of the source:  dataset: 1.000000
# Accuracy of the target:  dataset: 0.753333
#
#  epoch: 60, [iter: 3 / all 3], err_s_label: 0.077384, err_s_domain: 0.624153, err_t_domain: 0.541500
#
# Accuracy of the source:  dataset: 1.000000
# Accuracy of the target:  dataset: 0.750000
#
#  epoch: 61, [iter: 3 / all 3], err_s_label: 0.165473, err_s_domain: 0.564850, err_t_domain: 0.589575
#
# Accuracy of the source:  dataset: 1.000000
# Accuracy of the target:  dataset: 0.746667
#
#  epoch: 62, [iter: 3 / all 3], err_s_label: 0.220775, err_s_domain: 0.528324, err_t_domain: 0.616205
#
# Accuracy of the source:  dataset: 1.000000
# Accuracy of the target:  dataset: 0.750000
#
#  epoch: 63, [iter: 3 / all 3], err_s_label: 0.223615, err_s_domain: 0.566577, err_t_domain: 0.543124
#
# Accuracy of the source:  dataset: 1.000000
# Accuracy of the target:  dataset: 0.720000
#
#  epoch: 64, [iter: 3 / all 3], err_s_label: 0.187535, err_s_domain: 0.611773, err_t_domain: 0.636183
#
# Accuracy of the source:  dataset: 1.000000
# Accuracy of the target:  dataset: 0.733333
#
#  epoch: 65, [iter: 3 / all 3], err_s_label: 0.148046, err_s_domain: 0.571931, err_t_domain: 0.662184
#
# Accuracy of the source:  dataset: 1.000000
# Accuracy of the target:  dataset: 0.753333
#
#  epoch: 66, [iter: 3 / all 3], err_s_label: 0.109995, err_s_domain: 0.605396, err_t_domain: 0.516553
#
# Accuracy of the source:  dataset: 1.000000
# Accuracy of the target:  dataset: 0.743333
#
#  epoch: 67, [iter: 3 / all 3], err_s_label: 0.055882, err_s_domain: 0.583243, err_t_domain: 0.584228
#
# Accuracy of the source:  dataset: 1.000000
# Accuracy of the target:  dataset: 0.763333
#
#  epoch: 68, [iter: 3 / all 3], err_s_label: 0.089044, err_s_domain: 0.592300, err_t_domain: 0.576573
#
# Accuracy of the source:  dataset: 1.000000
# Accuracy of the target:  dataset: 0.760000
#
#  epoch: 69, [iter: 3 / all 3], err_s_label: 0.145735, err_s_domain: 0.551956, err_t_domain: 0.618971
#
# Accuracy of the source:  dataset: 1.000000
# Accuracy of the target:  dataset: 0.746667
#
#  epoch: 70, [iter: 3 / all 3], err_s_label: 0.259229, err_s_domain: 0.569280, err_t_domain: 0.555674
#
# Accuracy of the source:  dataset: 1.000000
# Accuracy of the target:  dataset: 0.756667
#
#  epoch: 71, [iter: 3 / all 3], err_s_label: 0.122030, err_s_domain: 0.597107, err_t_domain: 0.589956
#
# Accuracy of the source:  dataset: 1.000000
# Accuracy of the target:  dataset: 0.746667
#
#  epoch: 72, [iter: 3 / all 3], err_s_label: 0.137170, err_s_domain: 0.609578, err_t_domain: 0.659503
#
# Accuracy of the source:  dataset: 1.000000
# Accuracy of the target:  dataset: 0.743333
#
#  epoch: 73, [iter: 3 / all 3], err_s_label: 0.074022, err_s_domain: 0.576052, err_t_domain: 0.552756
#
# Accuracy of the source:  dataset: 0.996667
# Accuracy of the target:  dataset: 0.750000
#
#  epoch: 74, [iter: 3 / all 3], err_s_label: 0.226118, err_s_domain: 0.588088, err_t_domain: 0.646383
#
# Accuracy of the source:  dataset: 0.996667
# Accuracy of the target:  dataset: 0.766667
#
#  epoch: 75, [iter: 3 / all 3], err_s_label: 0.096753, err_s_domain: 0.601760, err_t_domain: 0.585475
#
# Accuracy of the source:  dataset: 0.996667
# Accuracy of the target:  dataset: 0.760000
#
#  epoch: 76, [iter: 3 / all 3], err_s_label: 0.120701, err_s_domain: 0.564809, err_t_domain: 0.680062
#
# Accuracy of the source:  dataset: 0.993333
# Accuracy of the target:  dataset: 0.786667
#
#  epoch: 77, [iter: 3 / all 3], err_s_label: 0.157556, err_s_domain: 0.604617, err_t_domain: 0.840249
#
# Accuracy of the source:  dataset: 0.993333
# Accuracy of the target:  dataset: 0.796667
#
#  epoch: 78, [iter: 3 / all 3], err_s_label: 0.139048, err_s_domain: 0.579822, err_t_domain: 0.580666
#
# Accuracy of the source:  dataset: 0.993333
# Accuracy of the target:  dataset: 0.786667
#
#  epoch: 79, [iter: 3 / all 3], err_s_label: 0.177593, err_s_domain: 0.647925, err_t_domain: 0.571257
#
# Accuracy of the source:  dataset: 0.996667
# Accuracy of the target:  dataset: 0.780000
#
#  epoch: 80, [iter: 3 / all 3], err_s_label: 0.142891, err_s_domain: 0.592724, err_t_domain: 0.565619
#
# Accuracy of the source:  dataset: 1.000000
# Accuracy of the target:  dataset: 0.760000
#
#  epoch: 81, [iter: 3 / all 3], err_s_label: 0.244527, err_s_domain: 0.619974, err_t_domain: 0.713495
#
# Accuracy of the source:  dataset: 1.000000
# Accuracy of the target:  dataset: 0.740000
#
#  epoch: 82, [iter: 3 / all 3], err_s_label: 0.145132, err_s_domain: 0.610379, err_t_domain: 0.634787
#
# Accuracy of the source:  dataset: 0.996667
# Accuracy of the target:  dataset: 0.736667
#
#  epoch: 83, [iter: 3 / all 3], err_s_label: 0.056495, err_s_domain: 0.584069, err_t_domain: 0.590338
#
# Accuracy of the source:  dataset: 0.996667
# Accuracy of the target:  dataset: 0.766667
#
#  epoch: 84, [iter: 3 / all 3], err_s_label: 0.118715, err_s_domain: 0.645660, err_t_domain: 0.488310
#
# Accuracy of the source:  dataset: 0.996667
# Accuracy of the target:  dataset: 0.770000
#
#  epoch: 85, [iter: 3 / all 3], err_s_label: 0.204490, err_s_domain: 0.590528, err_t_domain: 0.569804
#
# Accuracy of the source:  dataset: 0.996667
# Accuracy of the target:  dataset: 0.776667
#
#  epoch: 86, [iter: 3 / all 3], err_s_label: 0.314610, err_s_domain: 0.549527, err_t_domain: 0.673620
#
# Accuracy of the source:  dataset: 0.990000
# Accuracy of the target:  dataset: 0.766667
#
#  epoch: 87, [iter: 3 / all 3], err_s_label: 0.193651, err_s_domain: 0.554752, err_t_domain: 0.581195
#
# Accuracy of the source:  dataset: 0.990000
# Accuracy of the target:  dataset: 0.786667
#
#  epoch: 88, [iter: 3 / all 3], err_s_label: 0.113088, err_s_domain: 0.635001, err_t_domain: 0.517309
#
# Accuracy of the source:  dataset: 0.993333
# Accuracy of the target:  dataset: 0.770000
#
#  epoch: 89, [iter: 3 / all 3], err_s_label: 0.101500, err_s_domain: 0.600905, err_t_domain: 0.617192
#
# Accuracy of the source:  dataset: 1.000000
# Accuracy of the target:  dataset: 0.756667
#
#  epoch: 90, [iter: 3 / all 3], err_s_label: 0.189030, err_s_domain: 0.563886, err_t_domain: 0.584722
#
# Accuracy of the source:  dataset: 0.993333
# Accuracy of the target:  dataset: 0.753333
#
#  epoch: 91, [iter: 3 / all 3], err_s_label: 0.180808, err_s_domain: 0.621449, err_t_domain: 0.647416
#
# Accuracy of the source:  dataset: 0.980000
# Accuracy of the target:  dataset: 0.730000
#
#  epoch: 92, [iter: 3 / all 3], err_s_label: 0.197839, err_s_domain: 0.581116, err_t_domain: 0.607190
#
# Accuracy of the source:  dataset: 0.990000
# Accuracy of the target:  dataset: 0.746667
#
#  epoch: 93, [iter: 3 / all 3], err_s_label: 0.063003, err_s_domain: 0.505234, err_t_domain: 0.582606
#
# Accuracy of the source:  dataset: 0.990000
# Accuracy of the target:  dataset: 0.780000
#
#  epoch: 94, [iter: 3 / all 3], err_s_label: 0.167865, err_s_domain: 0.550883, err_t_domain: 0.526942
#
# Accuracy of the source:  dataset: 0.990000
# Accuracy of the target:  dataset: 0.773333
#
#  epoch: 95, [iter: 3 / all 3], err_s_label: 0.065421, err_s_domain: 0.533917, err_t_domain: 0.556881
#
# Accuracy of the source:  dataset: 0.996667
# Accuracy of the target:  dataset: 0.760000
#
#  epoch: 96, [iter: 3 / all 3], err_s_label: 0.211826, err_s_domain: 0.642990, err_t_domain: 0.522124
#
# Accuracy of the source:  dataset: 1.000000
# Accuracy of the target:  dataset: 0.776667
#
#  epoch: 97, [iter: 3 / all 3], err_s_label: 0.068037, err_s_domain: 0.522938, err_t_domain: 0.656486
#
# Accuracy of the source:  dataset: 1.000000
# Accuracy of the target:  dataset: 0.783333
#
#  epoch: 98, [iter: 3 / all 3], err_s_label: 0.131460, err_s_domain: 0.462193, err_t_domain: 0.509082
#
# Accuracy of the source:  dataset: 0.996667
# Accuracy of the target:  dataset: 0.780000
#
#  epoch: 99, [iter: 3 / all 3], err_s_label: 0.139837, err_s_domain: 0.479252, err_t_domain: 0.605951
#
# Accuracy of the source:  dataset: 0.996667
# Accuracy of the target:  dataset: 0.793333
